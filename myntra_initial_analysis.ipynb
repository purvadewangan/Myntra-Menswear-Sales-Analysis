# %%
import pandas as pd

# %%
df = pd.read_csv("myntra_dataset.csv")

# %%
df.head(10)
# Out:
#        brand_name              pants_description   price     MRP  \
# 0           WROGN     Men Loose Fit Cotton Jeans  1374.0  2499.0
# 1  Flying Machine             Men Slim Fit Jeans  1829.0  2999.0
# 2        Roadster          Men Pure Cotton Jeans   974.0  2499.0
# 3      Bene Kleed        Relaxed Fit Denim Jeans   873.0  2299.0
# 4           Levis         Men 511 Slim Fit Jeans  1478.0  2899.0
# 5        HERE&NOW          Men Stretchable Jeans   798.0  1699.0
# 6  Urbano Fashion          Men Relaxed Fit Jeans   944.0  2099.0
# 7           WROGN             Men Anti Fit Jeans  1623.0  2799.0
# 8      Bene Kleed  Men Wide Leg Heavy Fade Jeans   839.0  2799.0
# 9      Bene Kleed        Relaxed Fit Denim Jeans   873.0  2299.0
#
#    discount_percent  ratings  number_of_ratings
# 0              0.45      4.2               57.0
# 1              0.39      4.6                5.0
# 2              0.61      3.6             1100.0
# 3              0.62      4.0             4800.0
# 4              0.49      4.3              264.0
# 5              0.53      4.0               33.0
# 6              0.55      4.0             4200.0
# 7              0.42      4.2               42.0
# 8              0.70      3.6              114.0
# 9              0.62      4.1             5200.0

# %%
df.shape
# Out:
# (52120, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52120 entries, 0 to 52119
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand_name         52120 non-null  object
#  1   pants_description  52120 non-null  object
#  2   price              52120 non-null  float64
#  3   MRP                52120 non-null  float64
#  4   discount_percent   52120 non-null  float64
#  5   ratings            52120 non-null  float64
#  6   number_of_ratings  52120 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 2.8+ MB

# %%
df.describe()
# Out:
#               price           MRP  discount_percent       ratings  \
# count  52120.000000  52120.000000      52120.000000  52120.000000
# mean    1594.515445   3180.398438          1.648256      3.997794
# std     1495.972325   2201.883218          4.687529      0.420404
# min      337.000000    499.000000          0.020000      1.000000
# 25%      989.000000   2499.000000          0.400000      3.800000
# 50%     1439.000000   2999.000000          0.500000      4.000000
# 75%     1829.000000   3499.000000          0.630000      4.200000
# max    54000.000000  72000.000000         64.000000      5.000000
#
#        number_of_ratings
# count       52120.000000
# mean           91.568937
# std           433.918513
# min             5.000000
# 25%            16.000000
# 50%            35.000000
# 75%            74.000000
# max         30700.000000

# %%
df.isnull().sum()
# Out:
# brand_name           0
# pants_description    0
# price                0
# MRP                  0
# discount_percent     0
# ratings              0
# number_of_ratings    0
# dtype: int64

# %%
df.dtypes
# Out:
# brand_name            object
# pants_description     object
# price                float64
# MRP                  float64
# discount_percent     float64
# ratings              float64
# number_of_ratings    float64
# dtype: object

# %%
import numpy as np

# %% [markdown]
# # Creating a few columns for further analysis
# - **Effective Discount Percent** <br>
#       this will derive discount and demand relationship
# - **Rating Weighted** <br>
#       helps identify trustworthy and high performing products
# - **Value for Money Score** <br>
#       This will be useful for pricing optimization and competitive positioning
# - **Popularity Index** <br>
#       this will showcase overall product demand

# %%
# Creating column "effective_discount_percent"

df['effective_discount_percent'] = (
    (df['MRP'] - df['price']) / df['MRP']
) * 100

# %%
df.columns
# Out:
# Index(['brand_name', 'pants_description', 'price', 'MRP', 'discount_percent',
#        'ratings', 'number_of_ratings', 'effective_discount_percent'],
#       dtype='object')

# %%
# Creating column "rating_weighted"

df['rating_weighted'] = (
    df['ratings'] * np.log(df['number_of_ratings'] + 1)
)

# %%
df.columns
# Out:
# Index(['brand_name', 'pants_description', 'price', 'MRP', 'discount_percent',
#        'ratings', 'number_of_ratings', 'effective_discount_percent',
#        'rating_weighted'],
#       dtype='object')

# %%
# Creating column "value_for_money_score"

df['value_for_money_score'] = (
    df['ratings'] / (df['price'] / 1000)
)

# %%
df.columns
# Out:
# Index(['brand_name', 'pants_description', 'price', 'MRP', 'discount_percent',
#        'ratings', 'number_of_ratings', 'effective_discount_percent',
#        'rating_weighted', 'value_for_money_score'],
#       dtype='object')

# %%
# Creating column "popularity_index"

df['popularity_index'] = (
    df['rating_weighted'] +
    df['effective_discount_percent']
)

# %%
df.columns
# Out:
# Index(['brand_name', 'pants_description', 'price', 'MRP', 'discount_percent',
#        'ratings', 'number_of_ratings', 'effective_discount_percent',
#        'rating_weighted', 'value_for_money_score', 'popularity_index'],
#       dtype='object')

# %%
df.head()
# Out:
#        brand_name           pants_description   price     MRP  \
# 0           WROGN  Men Loose Fit Cotton Jeans  1374.0  2499.0
# 1  Flying Machine          Men Slim Fit Jeans  1829.0  2999.0
# 2        Roadster       Men Pure Cotton Jeans   974.0  2499.0
# 3      Bene Kleed     Relaxed Fit Denim Jeans   873.0  2299.0
# 4           Levis      Men 511 Slim Fit Jeans  1478.0  2899.0
#
#    discount_percent  ratings  number_of_ratings  effective_discount_percent  \
# 0              0.45      4.2               57.0                   45.018007
# 1              0.39      4.6                5.0                   39.013004
# 2              0.61      3.6             1100.0                   61.024410
# 3              0.62      4.0             4800.0                   62.026968
# 4              0.49      4.3              264.0                   49.016902
#
#    rating_weighted  value_for_money_score  popularity_index
# 0        17.053861               3.056769         62.071868
# 1         8.242094               2.515036         47.255098
# 2        25.214307               3.696099         86.238717
# 3        33.906318               4.581901         95.933286
# 4        23.992838               2.909337         73.009741

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52120 entries, 0 to 52119
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   brand_name                  52120 non-null  object
#  1   pants_description           52120 non-null  object
#  2   price                       52120 non-null  float64
#  3   MRP                         52120 non-null  float64
#  4   discount_percent            52120 non-null  float64
#  5   ratings                     52120 non-null  float64
#  6   number_of_ratings           52120 non-null  float64
#  7   effective_discount_percent  52120 non-null  float64
#  8   rating_weighted             52120 non-null  float64
#  9   value_for_money_score       52120 non-null  float64
#  10  popularity_index            52120 non-null  float64
# dtypes: float64(9), object(2)
# memory usage: 4.4+ MB

# %%
df.describe()
# Out:
#               price           MRP  discount_percent       ratings  \
# count  52120.000000  52120.000000      52120.000000  52120.000000
# mean    1594.515445   3180.398438          1.648256      3.997794
# std     1495.972325   2201.883218          4.687529      0.420404
# min      337.000000    499.000000          0.020000      1.000000
# 25%      989.000000   2499.000000          0.400000      3.800000
# 50%     1439.000000   2999.000000          0.500000      4.000000
# 75%     1829.000000   3499.000000          0.630000      4.200000
# max    54000.000000  72000.000000         64.000000      5.000000
#
#        number_of_ratings  effective_discount_percent  rating_weighted  \
# count       52120.000000                52120.000000     52120.000000
# mean           91.568937                   50.555769        14.498543
# std           433.918513                   14.780993         4.927046
# min             5.000000                    2.000488         1.791759
# 25%            16.000000                   40.011432        10.766211
# 50%            35.000000                   50.017864        13.689138
# 75%            74.000000                   61.016491        17.459905
# max         30700.000000                   86.135038        40.049547
#
#        value_for_money_score  popularity_index
# count           52120.000000      52120.000000
# mean                3.333369         65.054311
# std                 1.899091         15.383491
# min                 0.075362          7.833240
# 25%                 2.186987         56.579017
# 50%                 2.731870         64.536892
# 75%                 3.850932         76.208183
# max                12.698413        113.551152

# %%
#Save the file for further analysis

df.to_csv('myntra_menswear.csv', index=False)
